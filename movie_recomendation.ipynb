# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

movies = {
    'title': [
        'Avengers',
        'Iron Man',
        'Batman',
        'Superman',
        'Thor',
        'Titanic'
    ],

    'genre': [
        'Action Hero Sci-Fi',
        'Action Hero Tech',
        'Action Dark Hero',
        'Action Alien Hero',
        'Action Mythology Hero',
        'Romance Drama'
    ]
}

df = pd.DataFrame(movies)
print(df)

cv = CountVectorizer()

vectors = cv.fit_transform(df['genre'])

similarity = cosine_similarity(vectors)

def recommend(movie):

    movie_index = df[df['title'] == movie].index[0]
    distances = similarity[movie_index]

    movie_list = sorted(
        list(enumerate(distances)),
        reverse=True,
        key=lambda x: x[1]
)
    print("Recommended Movies:")
    for i in movie_list[1:4]:
        print(df.iloc[i[0]].title)
        
recommend('Batman')
# Out:
#       title                  genre
# 0  Avengers     Action Hero Sci-Fi
# 1  Iron Man       Action Hero Tech
# 2    Batman       Action Dark Hero
# 3  Superman      Action Alien Hero
# 4      Thor  Action Mythology Hero
# 5   Titanic          Romance Drama
# Recommended Movies:
# Iron Man
# Superman
# Thor
